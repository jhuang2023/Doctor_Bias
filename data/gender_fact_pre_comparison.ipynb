# %%
import pandas as pd

# %%
import numpy as np

# %%
Gender_com = pd.read_csv(open('GenderFact_Predict_Table.csv','rU'), encoding='utf-8', engine='c')
# Out:
# C:\Users\amyhu\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: 'U' mode is deprecated
#   if __name__ == '__main__':

# %%
Gender_com
# Out:
#                               name gender_fact first_name gender_pre
# 0                      a a durrani           M          a    Unknown
# 1                       a a hodari           F          a    Unknown
# 2                      a a kennedy           M          a    Unknown
# 3                       a a khalil           M          a    Unknown
# 4                      a a towfigh           M          a    Unknown
# 5                       a b belman           M          a    Unknown
# 6                         a b benz           M          a    Unknown
# 7                     a b chumbley           M          a    Unknown
# 8                       a b cosimi           M          a    Unknown
# 9                  a b lipscomb jr           M          a    Unknown
# 10                   a b wilcox jr           M          a    Unknown
# 11                        a c cage           M          a    Unknown
# 12                       a c heath           M          a    Unknown
# ...

# %%
Gender_com.gender_fact.isnull().sum()/len(Gender_com.gender_fact)
# Out:
# 0.14255983587354804

# %%
Gender_com.gender_pre.value_counts()
# Out:
# M          287566
# F          121719
# Unknown     30376
# Name: gender_pre, dtype: int64

# %%
Gender_com.gender_pre.value_counts()[2]/len(Gender_com.gender_pre)
# Out:
# 0.069089594028126214

# %%
Gender_com.gender_fact = Gender_com.gender_fact.fillna('Unknown')

# %%
Gender_com
# Out:
#                               name gender_fact first_name gender_pre
# 0                      a a durrani           M          a    Unknown
# 1                       a a hodari           F          a    Unknown
# 2                      a a kennedy           M          a    Unknown
# 3                       a a khalil           M          a    Unknown
# 4                      a a towfigh           M          a    Unknown
# 5                       a b belman           M          a    Unknown
# 6                         a b benz           M          a    Unknown
# 7                     a b chumbley           M          a    Unknown
# 8                       a b cosimi           M          a    Unknown
# 9                  a b lipscomb jr           M          a    Unknown
# 10                   a b wilcox jr           M          a    Unknown
# 11                        a c cage           M          a    Unknown
# 12                       a c heath           M          a    Unknown
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Gender_com.gender_fact, Gender_com.gender_pre)
# Out:
# 0.75873684497829008
